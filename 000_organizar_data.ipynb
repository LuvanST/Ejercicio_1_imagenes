# %%
import os
import pandas as pd
from google.cloud import storage

# Initialize the Google Cloud Storage client
client = storage.Client()

# %%
# Define the bucket and directories
bucket_name = 'declaraciones-renta-ai'
source_folder = 'data_pruebas/luvan_base_400_resultados/DEC_RENTA'
incorrect_folder = 'data_calidad_tercer_filtro/incorrectos_files'
correct_folder = 'data_calidad_tercer_filtro/correctos_files'

# %%
# Ensure directories exist
os.makedirs(incorrect_folder, exist_ok=True)
os.makedirs(correct_folder, exist_ok=True)

# %%
# Function to download files from GCP bucket
def download_files_from_bucket(file_names, download_folder, bucket_name, source_folder):
    bucket = client.bucket(bucket_name)
    for file_name in file_names:
        source_blob_name = f"{source_folder}/{file_name}"
        destination_file_name = os.path.join(download_folder, file_name)
        blob = bucket.blob(source_blob_name)
        if blob.exists():
            blob.download_to_filename(destination_file_name)
            print(f"Downloaded {file_name} to {download_folder}")
        else:
            print(f"File {file_name} not found in bucket.")

# %%
# Step 1: Read the bad files CSV and extract file names
df_bad = pd.read_csv('quality_score_ocr_premium_5 - bad_second_version.csv')
bad_files = df_bad['file_name'].tolist()

# Step 2: Download bad files
download_files_from_bucket(bad_files, incorrect_folder, bucket_name, source_folder)

# Step 3: Save the amount of downloaded files
amount_files = len(bad_files)
print(f"Number of bad files downloaded: {amount_files}")
# Out:
# Downloaded 1110518358_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded archivo4 (76)_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 41778530-mariela ochoa fonseca_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded archivo4 (78)_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 79536746_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded archivo4 - 2023-12-22t162748.693_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 42826276_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded archivo4 - 2023-12-21t151937.837_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 1022972783_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 7222437_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 42118379_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 15960765_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded cc 41960031_DR.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 32781969_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 7599706_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded copia de 1020444881_declaracionesrenta_110000610590.declarenta_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 11812777_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 544.declarenta (2)_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded archivo4 (79)_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 24720287_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 93435575_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 9531495_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 37625548_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 18495288_dr_consistentes_page_002.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 42826276_dr_inconsistentes_page_003.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded archivo4 - 2023-12-22t173350.614_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 9733837_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 8672437_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 79912113_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 10538090_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 24606406_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded archivo4 (5)_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 19489764_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 11379488_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 27090873_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 72170429_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 80116262_declaracionesrenta_110000643924.declarenta_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 37819037_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 52391071_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 27090873_dr_consistentes_page_002.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 37625548_dr_consistentes_page_002.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 16724819_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded archivo4 (2)_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 38863375_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 31581230_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 80137687_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 18597586_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 544.declarenta (2)_dr_page_002.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 21189618_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 72338414_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 1042995775_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 31834833_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 12138196_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 7176038-fredy alexander castellanos mesa_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 1094931203_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 53070082_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded archivo4 - 2023-12-21t163350.709_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 18495288_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 35527425_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 1094931203-natalia alejandra rodriguez antonio_decla_renta_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 8127249_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded archivo4 - 2023-12-26t005016.888_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 257552fc-38fc-4ae0-82ee-28393dcc11ad_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 4616379-john alexander meneses garcia_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 7711915_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded 24341919_dr_consistentes_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded archivo4f (3)_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded copia de 1070328683_declaracionesrenta_110000602659.declarenta_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Downloaded archivo4 - 2023-12-28t090833.771_dr_page_001.png to data_calidad_tercer_filtro/incorrectos_files
# Number of bad files downloaded: 69

# %%
# Step 4: Read the good files CSV and extract file names
df_good = pd.read_csv('quality_score_ocr_premium_5 - good.csv')
good_files = df_good['file_name'].tolist()

# Step 5: Reduce the good files list to the number of bad files
reduced_good_files = good_files[:amount_files]

# Step 6: Download the reduced list of good files
download_files_from_bucket(reduced_good_files, correct_folder, bucket_name, source_folder)

print(f"Downloaded {len(reduced_good_files)} good files to {correct_folder}")
# Out:
# Downloaded 23646877_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1013635023-2022_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 39794630_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded renta 2022 (1)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1045675943_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 19260000_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 22527776_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4 - 2023-12-21t141506.629_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 33311851_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 37274270_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 17653660_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 9148595_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 9148595_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1002497454_DR.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 22527776_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1032421431_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 24720287(2)_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 17653660_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 11281387_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1098644453-deisy johanna rodriguez avendano_decla_renta_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1098644453_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 13514125_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1022929374_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 19260000_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 530081932_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 37274270_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 31882934_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 9149391_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 13478032_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 8156297_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta (67)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1232597051_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 8672437_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 35488968_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1047442566_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1128386321_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 13838106_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1047442566_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 11281387_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 13514125_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 9149391_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta - 2023-12-09t140304.450_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta - 2023-12-09t140839.394_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4 (75)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1128386321_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 9191830 jose maria sanchez ordonez_DR.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1143932832_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 17655718_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 45741027_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 16780175_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 34572469_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 42826276_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta - 2023-12-10t184031.977_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 1035442051_declaracionesrenta_110000575712.declarenta_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4 (1)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 16750727_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 530081932_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 17311392_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 16750727-jaime ascarate alvarez 2022_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1004752982_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4 (95)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4 (4)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 7536369_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4 - 2023-12-22t122303.834_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1052401466_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4 - 2023-12-22t100750.560_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 17311392_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1030546873-ana milena sierra vergara 2022_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 71763816_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 69 good files to data_calidad_tercer_filtro/correctos_files

# %%
df_good = pd.read_csv('quality_score_ocr_premium_5 - good.csv')
good_files = df_good['file_name'].tolist()


# # Step 7: Extract 50 files after the reduced_good_files
# start_index = len(reduced_good_files)
# end_index = start_index + 50
# reduced_good_files_50 = good_files[start_index:end_index]

# %%
len(good_files)
# Out:
# 367

# %%
# Step 8: Download the reduced list of good files
download_files_from_bucket(good_files, "data_calidad_tercer_filtro/correctos_files", bucket_name, source_folder)

print(f"Downloaded {len(good_files)} good files to data_calidad_tercer_filtro/correctos_files")
# Out:
# Downloaded 23646877_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1013635023-2022_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 39794630_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded renta 2022 (1)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1045675943_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 19260000_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 22527776_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4 - 2023-12-21t141506.629_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 33311851_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 37274270_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 17653660_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 9148595_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 9148595_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1002497454_DR.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 22527776_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1032421431_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 24720287(2)_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 17653660_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 11281387_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1098644453-deisy johanna rodriguez avendano_decla_renta_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1098644453_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 13514125_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1022929374_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 19260000_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 530081932_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 37274270_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 31882934_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 9149391_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 13478032_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 8156297_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta (67)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1232597051_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 8672437_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 35488968_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1047442566_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1128386321_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 13838106_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1047442566_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 11281387_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 13514125_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 9149391_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta - 2023-12-09t140304.450_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta - 2023-12-09t140839.394_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4 (75)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1128386321_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 9191830 jose maria sanchez ordonez_DR.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1143932832_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 17655718_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 45741027_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 16780175_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 34572469_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 42826276_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta - 2023-12-10t184031.977_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 1035442051_declaracionesrenta_110000575712.declarenta_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4 (1)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 16750727_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 530081932_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 17311392_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 16750727-jaime ascarate alvarez 2022_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1004752982_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4 (95)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4 (4)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 7536369_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4 - 2023-12-22t122303.834_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1052401466_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4 - 2023-12-22t100750.560_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 17311392_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1030546873-ana milena sierra vergara 2022_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 71763816_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 10268656 2022_DR.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 28211313_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4 - 2023-12-26t141241.098_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 12021856 ronald antonio rios mosquera_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 
_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 79778061_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 544.declarenta(3)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 7302845_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta (64)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 80902836_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1118545969_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 83029244_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta - 2023-12-08t115756.475_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 51894444_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta (1)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 544.declarenta(14)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 39676084_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1032453615-camila ussa villamil_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 29817451_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 29127947_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta (21)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 7551421_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta (23)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 15817481-oscar esteban micanquer eraso 2022_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1024551442_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 544.declarenta (1)(1)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 544.declarenta (1)(2)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1095915020_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 15453658_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 16840794_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta (64)_dr_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 79493919_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 544.declarenta(17)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 86053795_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta - 2023-12-17t114204.972_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 79738368_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1063959504_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 7c631e0c-8956-42da-9894-0fb89148f791_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 544.declarenta (1)(4)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 544.declarenta(15)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta (41)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 43161404-darling urrea baena 2021_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 45450707_declaracionesrenta_110000623555.declarenta_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 24720287(1)_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 52725243_declaracionesrenta_110000545857.declarenta_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1095915020_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded dr (2)_decla_renta_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta - 2023-12-10t173900.153_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1033806798_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 29817451_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta (65)_dr_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 544.declarenta(2)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 544.declarenta(1)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 19486132_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 19486132_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 11231819_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 9432071_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 544.declarenta(21)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta - 2023-12-11t150423.856_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1122126105_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 5609407_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 5531716_dr_consistentes_page_003.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1122122489_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 7302845_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta - 2023-12-08t114825.335_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 7551421_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1022941496_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 544.declarenta(9)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 42894436_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 39749507_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 43161404-darling urrea baena 2022_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1082878482_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 16840794_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 11231819_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 79493919_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded cc 7223507_DR.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1022941496_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 10228241_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta - 2023-12-10t153802.981_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 544.declarenta (1)(3)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 91238364_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 19304147_dr_consistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4 - 2023-12-26t142042.588_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1140892109_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta (24)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 79536746_dr_inconsistentes_page_002.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 13838106_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 5912385_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 544.declarenta(18)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 544.declarenta(11)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded archivo4f (9)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 71763816_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 544.declarenta(19)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1121867726_declaracionesrenta_110000584313.declarenta_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta - 2023-12-08t113447.701_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1140892109_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 544.declarenta(7)_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 1143958147_dr_inconsistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 10228241_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 1017193446_declaracionesrenta_110000573991.declarenta_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta - 2023-12-08t114947.549_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 3834dec1-9dca-44a8-ae77-1f9f83703b7f_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 39153911_dr_consistentes_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 544.declarenta - 2023-12-17t103926.630_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 16078928 2022_DR.png to data_calidad_tercer_filtro/correctos_files
# Downloaded copia de 1129570737_declaracionesrenta_110000484995.declarenta_dr_page_001.png to data_calidad_tercer_filtro/correctos_files
# Downloaded 367 good files to data_calidad_tercer_filtro/correctos_files

# %%
import os
import cv2
import numpy as np
from concurrent.futures import ThreadPoolExecutor, as_completed
from concurrent.futures import ProcessPoolExecutor, as_completed

# Functions to apply image transformations
def apply_blur(image, ksize=(5, 5)):
    return cv2.GaussianBlur(image, ksize, 0)

def add_noise(image, mean=0, sigma=10):
    gauss = np.random.normal(mean, sigma, image.shape).astype('uint8')
    noisy_image = cv2.add(image, gauss)
    return noisy_image

# Function to reduce contrast
def reduce_contrast(image, factor=0.5):
    # Convert to LAB color space to manipulate contrast
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    
    # Apply contrast reduction on the L channel
    l = cv2.addWeighted(l, factor, l, 0, 128*(1-factor))
    
    # Merge and convert back to BGR
    lab = cv2.merge((l, a, b))
    return cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)

# Function to apply JPEG compression (simulates compression artifacts)
def jpeg_compression(image, quality=30):
    encode_param = [int(cv2.IMWRITE_JPEG_QUALITY), quality]
    result, encimg = cv2.imencode('.jpg', image, encode_param)
    return cv2.imdecode(encimg, 1)

def process_image(file_name, input_folder, output_folder):
    input_file_path = os.path.join(input_folder, file_name)
    output_file_path = os.path.join(output_folder, file_name)

    # Read the image
    image = cv2.imread(input_file_path)
    
    if image is None:
        print(f"Error loading image: {input_file_path}")
        return

    # Apply transformations
    image_mod = apply_blur(image, ksize=(5, 5))
    image_mod = add_noise(image_mod, mean=5, sigma=5)
    image_mod = reduce_contrast(image_mod, factor=0.99)

    # Save the transformed image to the output directory
    cv2.imwrite(output_file_path, image_mod)

    print(f"Processed and saved image: {output_file_path}")
    return output_file_path

# Parallel processing function
def parallel_process_images(png_files, input_folder, output_folder, max_workers):
    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        # Submit all tasks to the thread pool
        futures = [executor.submit(process_image, file_name, input_folder, output_folder) for file_name in png_files]
        
        # Wait for all tasks to complete and process the results
        for future in as_completed(futures):
            try:
                result = future.result()
                print(f"Completed processing: {result}")
            except Exception as exc:
                print(f"Exception occurred: {exc}")

# Example usage
input_folder = 'data_calidad_tercer_filtro/correctos_files'
output_folder = 'data_calidad_tercer_filtro/incorrectos_files'
png_files = [f for f in os.listdir(input_folder) if f.endswith('.png')]

parallel_process_images(png_files, input_folder, output_folder, max_workers=32)
# Out:
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/17655718_dr_consistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/17655718_dr_consistentes_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/544.declarenta - 2023-12-09t140615.325_dr_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/24370790_dr_consistentes_page_002.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/51894444_dr_inconsistentes_page_002.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/copia de 544.declarenta(15)_dr_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/544.declarenta - 2023-12-17t103926.630_dr_page_001.pngCompleted processing: data_calidad_tercer_filtro/incorrectos_files/544.declarenta - 2023-12-09t140615.325_dr_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/24370790_dr_consistentes_page_002.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/51894444_dr_inconsistentes_page_002.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/copia de 544.declarenta(15)_dr_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/11231819_dr_consistentes_page_002.png
#
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/98581406_dr_inconsistentes_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/43564230_dr_inconsistentes_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/544.declarenta - 2023-12-11t150423.856_dr_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/1082878482_dr_inconsistentes_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/544.declarenta - 2023-12-07t112031.415_dr_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/544.declarenta - 2023-12-17t103926.630_dr_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/11231819_dr_consistentes_page_002.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/98581406_dr_inconsistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/43564230_dr_inconsistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/544.declarenta - 2023-12-11t150423.856_dr_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/1082878482_dr_inconsistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/544.declarenta - 2023-12-07t112031.415_dr_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/52316468-viviana marcela paez alayon_dr_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/1143368218_dr_inconsistentes_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/1047442566_dr_inconsistentes_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/30721549_dr_consistentes_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/544.declarenta - 2023-12-08t115317.820_dr_page_001.pngProcessed and saved image: data_calidad_tercer_filtro/incorrectos_files/13478032_dr_consistentes_page_001.pngProcessed and saved image: data_calidad_tercer_filtro/incorrectos_files/5609407_dr_consistentes_page_001.png
#
#
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/52316468-viviana marcela paez alayon_dr_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/1143368218_dr_inconsistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/1047442566_dr_inconsistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/30721549_dr_consistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/544.declarenta - 2023-12-08t115317.820_dr_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/13478032_dr_consistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/5609407_dr_consistentes_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/15453658_dr_consistentes_page_002.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/1043000445_dr_inconsistentes_page_002.pngProcessed and saved image: data_calidad_tercer_filtro/incorrectos_files/1107514465_dr_inconsistentes_page_001.png
#
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/1129568902_dr_inconsistentes_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/9149391_dr_inconsistentes_page_002.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/17653660_dr_consistentes_page_002.pngProcessed and saved image: data_calidad_tercer_filtro/incorrectos_files/178973_dr_consistentes_page_001.pngProcessed and saved image: data_calidad_tercer_filtro/incorrectos_files/9148595_dr_inconsistentes_page_001.pngProcessed and saved image: data_calidad_tercer_filtro/incorrectos_files/544.declarenta - 2023-12-10t183543.891_dr_page_001.pngProcessed and saved image: data_calidad_tercer_filtro/incorrectos_files/16865184_dr_consistentes_page_001.png
#
#
#
#
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/12021856 ronald antonio rios mosquera_dr_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/15453658_dr_consistentes_page_002.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/1043000445_dr_inconsistentes_page_002.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/1107514465_dr_inconsistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/1129568902_dr_inconsistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/9149391_dr_inconsistentes_page_002.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/9148595_dr_inconsistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/17653660_dr_consistentes_page_002.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/16865184_dr_consistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/544.declarenta - 2023-12-10t183543.891_dr_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/178973_dr_consistentes_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/1144090226 dr (1)_decla_renta_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/1013635023-2022_dr_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/12021856 ronald antonio rios mosquera_dr_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/1144090226 dr (1)_decla_renta_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/1013635023-2022_dr_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/12116301_dr_consistentes_page_002.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/12116301_dr_consistentes_page_002.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/39153911_dr_consistentes_page_002.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/1033806798_dr_inconsistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/39153911_dr_consistentes_page_002.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/1033806798_dr_inconsistentes_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/1045675943_dr_inconsistentes_page_001.pngProcessed and saved image: data_calidad_tercer_filtro/incorrectos_files/544.declarenta (71)_dr_page_001.png
#
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/544.declarenta (6)_dr_page_001.pngProcessed and saved image: data_calidad_tercer_filtro/incorrectos_files/1140892109_dr_inconsistentes_page_002.png
#
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/530081932_dr_inconsistentes_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/19486132_dr_consistentes_page_002.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/544.declarenta (71)_dr_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/1045675943_dr_inconsistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/544.declarenta (6)_dr_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/1140892109_dr_inconsistentes_page_002.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/530081932_dr_inconsistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/19486132_dr_consistentes_page_002.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/544.declarenta (62) (1)_dr_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/5531716_dr_consistentes_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/33703124_dr_consistentes_page_002.pngProcessed and saved image: data_calidad_tercer_filtro/incorrectos_files/11231819_dr_consistentes_page_001.png
#
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/5531716_dr_consistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/544.declarenta (62) (1)_dr_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/11231819_dr_consistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/33703124_dr_consistentes_page_002.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/34373797_dr_consistentes_page_001.pngProcessed and saved image: data_calidad_tercer_filtro/incorrectos_files/1063959504_dr_inconsistentes_page_002.pngProcessed and saved image: data_calidad_tercer_filtro/incorrectos_files/13838106_dr_consistentes_page_002.png
#
#
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/1022929374_dr_inconsistentes_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/34572469_dr_consistentes_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/1022941496_dr_inconsistentes_page_002.pngCompleted processing: data_calidad_tercer_filtro/incorrectos_files/1063959504_dr_inconsistentes_page_002.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/13838106_dr_consistentes_page_002.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/34373797_dr_consistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/1022929374_dr_inconsistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/34572469_dr_consistentes_page_001.png
#
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/7302845_dr_consistentes_page_002.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/52261093_dr_inconsistentes_page_001.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/1022941496_dr_inconsistentes_page_002.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/7302845_dr_consistentes_page_002.png
# Completed processing: data_calidad_tercer_filtro/incorrectos_files/52261093_dr_inconsistentes_page_001.png
# Processed and saved image: data_calidad_tercer_filtro/incorrectos_files/35488968_dr_consistentes_page_001.pngProcessed and saved image: data_calidad_tercer_filtro/incorrectos_files